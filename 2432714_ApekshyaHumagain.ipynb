# %% [markdown]
# 3.1 Problem-1
# 1.Data Exploration

# %%
#importing libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import warnings
import seaborn as sns#loading data set
data_set = pd.read_csv('C:\\Users\\user\\OneDrive\\Desktop\\WHR-2024-5CS037.csv')
data_set
# Out:
#          Country name  score  Log GDP per capita  Social support  \
# 0             Finland  7.741               1.844           1.572
# 1             Denmark  7.583               1.908           1.520
# 2             Iceland  7.525               1.881           1.617
# 3              Sweden  7.344               1.878           1.501
# 4              Israel  7.341               1.803           1.513
# ..                ...    ...                 ...             ...
# 138  Congo (Kinshasa)  3.295               0.534           0.665
# 139      Sierra Leone  3.245               0.654           0.566
# 140           Lesotho  3.186               0.771           0.851
# 141           Lebanon  2.707               1.377           0.577
# 142       Afghanistan  1.721               0.628           0.000
#
#      Healthy life expectancy  Freedom to make life choices  Generosity  \
# 0                      0.695                         0.859       0.142
# ...

# %%
#displaying first 10 rows
data_set.head(10)
# Out:
#   Country name  score  Log GDP per capita  Social support  \
# 0      Finland  7.741               1.844           1.572
# 1      Denmark  7.583               1.908           1.520
# 2      Iceland  7.525               1.881           1.617
# 3       Sweden  7.344               1.878           1.501
# 4       Israel  7.341               1.803           1.513
# 5  Netherlands  7.319               1.901           1.462
# 6       Norway  7.302               1.952           1.517
# 7   Luxembourg  7.122               2.141           1.355
# 8  Switzerland  7.060               1.970           1.425
# 9    Australia  7.057               1.854           1.461
#
#    Healthy life expectancy  Freedom to make life choices  Generosity  \
# 0                    0.695                         0.859       0.142
# 1                    0.699                         0.823       0.204
# 2                    0.718                         0.819       0.258
# ...

# %%
#identifying the number rows and columns in the dataset
rows , columns = data_set.shape

print("The total number of rows present in the dataset:", rows)
print("The total number of columns present in the dataset:", columns)
# Out:
# The total number of rows present in the dataset: 143
# The total number of columns present in the dataset: 9

# %%
# all the columns and their data types
data_set.dtypes
# Out:
# Country name                     object
# score                           float64
# Log GDP per capita              float64
# Social support                  float64
# Healthy life expectancy         float64
# Freedom to make life choices    float64
# Generosity                      float64
# Perceptions of corruption       float64
# Dystopia + residual             float64
# dtype: object

# %%
# calculation of mean, median,standard deviation for Score column
print("Mean of score column:",data_set['score'].mean())
print("Median of score column:",data_set['score'].median())
print("Standard deviation :",data_set['score'].std())
# Out:
# Mean of score column: 5.52758041958042
# Median of score column: 5.785
# Standard deviation : 1.1707165099442993

# %%
#other statistical data
data_set.describe()
# Out:
#             score  Log GDP per capita  Social support  \
# count  143.000000          140.000000      140.000000
# mean     5.527580            1.378807        1.134329
# std      1.170717            0.425098        0.333317
# min      1.721000            0.000000        0.000000
# 25%      4.726000            1.077750        0.921750
# 50%      5.785000            1.431500        1.237500
# 75%      6.416000            1.741500        1.383250
# max      7.741000            2.141000        1.617000
#
#        Healthy life expectancy  Freedom to make life choices  Generosity  \
# count               140.000000                    140.000000  140.000000
# mean                  0.520886                      0.620621    0.146271
# std                   0.164923                      0.162492    0.073441
# min                   0.000000                      0.000000    0.000000
# 25%                   0.398000                      0.527500    0.091000
# ...

# %%
# Country with highest and lowest happiness score
print("Country with highest happiness score is", data_set.loc[data_set['score'].idxmax(), 'Country name'],"with score:", data_set['score'].max())
print("Country with lowest happiness score is", data_set.loc[data_set['score'].idxmin(), 'Country name'],"with score:", data_set['score'].min())
# Out:
# Country with highest happiness score is Finland with score: 7.741
# Country with lowest happiness score is Afghanistan with score: 1.721

# %%
# Checking if there are any missing values and displaying total count for each column
data_set.isnull().sum()
# Out:
# Country name                    0
# score                           0
# Log GDP per capita              3
# Social support                  3
# Healthy life expectancy         3
# Freedom to make life choices    3
# Generosity                      3
# Perceptions of corruption       3
# Dystopia + residual             3
# dtype: int64

# %%
data_set[data_set.isnull().any(axis=1)]
# Out:
#            Country name  score  Log GDP per capita  Social support  \
# 61              Bahrain  5.959                 NaN             NaN
# 87           Tajikistan  5.281                 NaN             NaN
# 102  State of Palestine  4.879                 NaN             NaN
#
#      Healthy life expectancy  Freedom to make life choices  Generosity  \
# 61                       NaN                           NaN         NaN
# 87                       NaN                           NaN         NaN
# 102                      NaN                           NaN         NaN
#
#      Perceptions of corruption  Dystopia + residual
# 61                         NaN                  NaN
# 87                         NaN                  NaN
# 102                        NaN                  NaN

# %%
#dropping the rows with high null values
data_set.drop(index=[61, 87, 102], inplace=True)
data_set.to_csv('WHR-2024-5CS037.csv', index=False)

# %%
#data_set after drop
data_set
# Out:
#          Country name  score  Log GDP per capita  Social support  \
# 0             Finland  7.741               1.844           1.572
# 1             Denmark  7.583               1.908           1.520
# 2             Iceland  7.525               1.881           1.617
# 3              Sweden  7.344               1.878           1.501
# 4              Israel  7.341               1.803           1.513
# ..                ...    ...                 ...             ...
# 138  Congo (Kinshasa)  3.295               0.534           0.665
# 139      Sierra Leone  3.245               0.654           0.566
# 140           Lesotho  3.186               0.771           0.851
# 141           Lebanon  2.707               1.377           0.577
# 142       Afghanistan  1.721               0.628           0.000
#
#      Healthy life expectancy  Freedom to make life choices  Generosity  \
# 0                      0.695                         0.859       0.142
# ...

# %%
# Fill null values 
warnings.filterwarnings("ignore")

data_set["Log GDP per capita"].fillna(data_set["Log GDP per capita"].mean(), inplace=True)
data_set["Healthy life expectancy"].fillna(data_set["Healthy life expectancy"].mean(), inplace=True)
data_set["Social support"].fillna(data_set["Social support"].mean(), inplace=True)
data_set["Freedom to make life choices"].fillna(data_set["Freedom to make life choices"].mean(), inplace=True)
data_set["Generosity"].fillna(data_set["Generosity"].median(), inplace=True)
data_set["Perceptions of corruption"].fillna(data_set["Perceptions of corruption"].median(), inplace=True)
data_set["Dystopia + residual"].fillna(data_set["Dystopia + residual"].mean(), inplace=True)

data_set.to_csv('WHR-2024-5CS037.csv', index=False)
print("CSV file saved successfully.")
# Out:
# CSV file saved successfully.

# %%
print(data_set.isnull().sum())
# Out:
# Country name                    0
# score                           0
# Log GDP per capita              0
# Social support                  0
# Healthy life expectancy         0
# Freedom to make life choices    0
# Generosity                      0
# Perceptions of corruption       0
# Dystopia + residual             0
# dtype: int64

# %%
# Filtering
data_set[data_set['score']>7.5][['Country name','score']]
# Out:
#   Country name  score
# 0      Finland  7.741
# 1      Denmark  7.583
# 2      Iceland  7.525

# %%
# Sorting GDP into descending order
data_set.sort_values(by='Log GDP per capita', ascending=False)[['Country name','Log GDP per capita']].head(10)
# Out:
#                  Country name  Log GDP per capita
# 7                  Luxembourg               2.141
# 16                    Ireland               2.129
# 29                  Singapore               2.118
# 21       United Arab Emirates               1.983
# 8                 Switzerland               1.970
# 6                      Norway               1.952
# 22              United States               1.939
# 85  Hong Kong S.A.R. of China               1.909
# 1                     Denmark               1.908
# 5                 Netherlands               1.901

# %%
#Adding Happiness_Category column
data_set['Happiness_Category'] = np.where(data_set['score'] < 4, 'Low',np.where((data_set['score'] >= 4) & (data_set['score'] <= 6), 'Medium', 'High'))
data_set[['Country name', 'score', 'Happiness_Category']]
# Out:
#          Country name  score Happiness_Category
# 0             Finland  7.741               High
# 1             Denmark  7.583               High
# 2             Iceland  7.525               High
# 3              Sweden  7.344               High
# 4              Israel  7.341               High
# ..                ...    ...                ...
# 138  Congo (Kinshasa)  3.295                Low
# 139      Sierra Leone  3.245                Low
# 140           Lesotho  3.186                Low
# 141           Lebanon  2.707                Low
# 142       Afghanistan  1.721                Low
#
# [140 rows x 3 columns]

# %% [markdown]
# 2.Data Visualization

# %%
# Bar Plot
data_set = pd.read_csv('WHR-2024-5CS037.csv')
sorted_data_set = data_set.sort_values(by = 'score',ascending = False).head(10)

sns.barplot(x=sorted_data_set['Country name'],y=sorted_data_set['score'],color = 'salmon')
plt.title("Top 10 happiest countries")
plt.xticks(rotation=90)
plt.show()

# %%
# Line Plot
data_set = pd.read_csv('WHR-2024-5CS037.csv')
sorted_data_set = data_set.sort_values(by = 'score',ascending = True).head(10)
plt.title("Top 10 unhappiest countries")

sns.lineplot(x=sorted_data_set['Country name'],y=sorted_data_set['score'],color = 'blue')
plt.xticks(rotation=90)
plt.show()

# %%
#histogram 
data_set = pd.read_csv('WHR-2024-5CS037.csv')

sns.histplot(data=data_set, x='score', bins=30, color='lightblue')

plt.xlabel("Score")
plt.ylabel("Frequency")
plt.title("Distribution of Scores")

plt.show()

# %%
#scatterplot
data_set = pd.read_csv('WHR-2024-5CS037.csv').head(40)
sns.scatterplot(x=data_set['Log GDP per capita'], y=data_set['score'], color='blue')
plt.xticks(rotation=90)
plt.title("GDP per Capita vs Score")
plt.xlabel('Log GDP per Capita')
plt.ylabel('Score')

plt.show()

# %% [markdown]
# 3.2 Problem 2
# 1.Setup Task

# %%
# filtering south asian countries

data_set = pd.read_csv('WHR-2024-5CS037.csv')
south_asian_countries = ["Afghanistan", "Bangladesh", "Bhutan", "India", "Maldives", "Nepal", "Pakistan", "Sri Lanka"]
south_asian_data = data_set[data_set['Country name'].isin(south_asian_countries)]
south_asian_data.to_csv('south_asian_countries_filtered.csv', index=False)
south_asian_data
# Out:
#     Country name  score  Log GDP per capita  Social support  \
# 90         Nepal  5.158               0.965           0.990
# 104     Pakistan  4.657               1.069           0.600
# 122        India  4.054               1.166           0.653
# 124    Sri Lanka  3.898               1.361           1.179
# 125   Bangladesh  3.886               1.122           0.249
# 139  Afghanistan  1.721               0.628           0.000
#
#      Healthy life expectancy  Freedom to make life choices  Generosity  \
# 90                     0.443                         0.653       0.209
# 104                    0.321                         0.542       0.144
# 122                    0.417                         0.767       0.174
# 124                    0.586                         0.583       0.144
# 125                    0.513                         0.775       0.140
# 139                    0.242                         0.000       0.091
#
# ...

# %% [markdown]
# 2.Composite Score Ranking

# %%
# creating new column 'Composite Score'
warnings.filterwarnings("ignore")

composite_score = 0.40 * south_asian_data['Log GDP per capita'] + 0.30 * south_asian_data['Social support'] + 0.30 * south_asian_data['Healthy life expectancy']
south_asian_data['Composite Score'] = composite_score
south_asian_data
# Out:
#     Country name  score  Log GDP per capita  Social support  \
# 90         Nepal  5.158               0.965           0.990
# 104     Pakistan  4.657               1.069           0.600
# 122        India  4.054               1.166           0.653
# 124    Sri Lanka  3.898               1.361           1.179
# 125   Bangladesh  3.886               1.122           0.249
# 139  Afghanistan  1.721               0.628           0.000
#
#      Healthy life expectancy  Freedom to make life choices  Generosity  \
# 90                     0.443                         0.653       0.209
# 104                    0.321                         0.542       0.144
# 122                    0.417                         0.767       0.174
# 124                    0.586                         0.583       0.144
# 125                    0.513                         0.775       0.140
# 139                    0.242                         0.000       0.091
#
# ...

# %%
#  Composite Score in descending order
sorted_south_asian_data = south_asian_data.sort_values(by='Composite Score', ascending=False)

sorted_south_asian_data[['Country name', 'Composite Score']]
# Out:
#     Country name  Composite Score
# 124    Sri Lanka           1.0739
# 90         Nepal           0.8159
# 122        India           0.7874
# 104     Pakistan           0.7039
# 125   Bangladesh           0.6774
# 139  Afghanistan           0.3238

# %%
#Score in descending order
sorted_south_asian_data = south_asian_data.sort_values(by='score', ascending=False)

sorted_south_asian_data[['Country name', 'score']]
# Out:
#     Country name  score
# 90         Nepal  5.158
# 104     Pakistan  4.657
# 122        India  4.054
# 124    Sri Lanka  3.898
# 125   Bangladesh  3.886
# 139  Afghanistan  1.721

# %%
#visualizing top five countries based on Composite Score
top_five_data = sorted_south_asian_data.head()
sns.barplot(x =top_five_data["Composite Score"], y= top_five_data["Country name"],color ="#F4A460")
plt.title("Top five countries with Composite Score")
plt.xlabel("Composite Score")
plt.ylabel("Countries")
# Out:
# Text(0, 0.5, 'Countries')

# %%
# rankings based on the Composite Score align with the original Score
import matplotlib.pyplot as plt

# Assuming 'south_asian_data' is a pandas DataFrame containing the data
countries = south_asian_data['Country name']
original_score = south_asian_data['score']
composite_score = south_asian_data['Composite Score']

plt.figure(figsize=(10, 8))
plt.plot(countries, original_score, marker='o', color='purple', label='Original Score')
plt.plot(countries, composite_score, marker='o', color='skyblue', label='Composite Score')

plt.title('Original Score vs Composite Score')
plt.xlabel('Countries')
plt.ylabel('Scores')
plt.legend()
plt.grid(True, linestyle='--', alpha=0.6)
plt.show()

# %% [markdown]
# 3 Outlier Detection:

# %%
#detecting GDP and score outliers
# Outliers for 'score'
Q1_s = np.percentile(south_asian_data['score'], 25)
Q3_s = np.percentile(south_asian_data['score'], 75)
IQR_s = Q3_s - Q1_s
lb_s = Q1_s - 1.5 * IQR_s
ub_s = Q3_s + 1.5 * IQR_s
out_s = south_asian_data[(south_asian_data['score'] < lb_s) | (south_asian_data['score'] > ub_s)]

# Outliers for 'Log GDP per capita'
Q1_g = np.percentile(south_asian_data['Log GDP per capita'], 25)
Q3_g = np.percentile(south_asian_data['Log GDP per capita'], 75)
IQR_g = Q3_g - Q1_g
lb_g = Q1_g - 1.5 * IQR_g #lower bound
ub_g = Q3_g + 1.5 * IQR_g #upper bound
out_g = south_asian_data[(south_asian_data['Log GDP per capita'] < lb_g) | (south_asian_data['Log GDP per capita'] > ub_g)]

# Concise output
print("Score outliers:", out_s['Country name'].tolist()) 
print("GDP per capita outliers:", out_g['Country name'].tolist())
# Out:
# Score outliers: ['Afghanistan']
# GDP per capita outliers: ['Afghanistan']

# %%
#plotting
plt.scatter(south_asian_data['Log GDP per capita'], south_asian_data['score'], label='Normal', color='green')
plt.scatter(out_g['Log GDP per capita'], out_s['score'], label='Outliers', color='red')

plt.xlim(0.5, 1.5)  
plt.ylim(0, 5.5)

plt.xlabel('Log GDP per capita')
plt.ylabel('Score')
plt.title('South Asia:GDP per Capita vs Score')
plt.legend()
plt.show()

# %% [markdown]
# 4.Exploring trends across metrics

# %%
#Calculating correlation

south_asian_data = pd.read_csv("south_asian_countries_filtered.csv")

life_choices_corr = south_asian_data['Freedom to make life choices'].corr(south_asian_data['score'])
generosity_corr = south_asian_data['Generosity'].corr(south_asian_data['score'])

print("'Freedom to make life choices' correlation with score:", life_choices_corr)
print("'Generosity' correlation with score:", generosity_corr) #has strongest relationship
# Out:
# 'Freedom to make life choices' correlation with score: 0.8005185224163315
# 'Generosity' correlation with score: 0.874512371253192

# %%
# plotting the correlations
import seaborn as sns
import matplotlib.pyplot as plt
south_asian_data = pd.read_csv("south_asian_countries_filtered.csv")


plt.figure(figsize=(8, 6))
sns.regplot(x=south_asian_data['Freedom to make life choices'], y=south_asian_data['score'], line_kws={'color': 'purple'})
plt.title(f'Freedom to make life choices vs score\nPearson Correlation: {life_choices_corr:.2f}')
plt.xlabel('Freedom to make life choices')
plt.ylabel('score')
plt.show()

plt.figure(figsize=(8, 6))
sns.regplot(x=south_asian_data['Generosity'], y=south_asian_data['score'], line_kws={'color': 'purple'})
plt.title(f'Generosity vs score\nPearson Correlation: {generosity_corr:.2f}') 
plt.xlabel('Generosity')
plt.ylabel('score')
plt.show()

# %% [markdown]
# 5.Gap Analysis

# %%
#adding new column 'GDP-Score Gap'
south_asian_data = pd.read_csv("south_asian_countries_filtered.csv")
south_asian_data['GDP-Score Gap'] = south_asian_data['score']-south_asian_data['Log GDP per capita']
south_asian_data
# Out:
#   Country name  score  Log GDP per capita  Social support  \
# 0        Nepal  5.158               0.965           0.990
# 1     Pakistan  4.657               1.069           0.600
# 2        India  4.054               1.166           0.653
# 3    Sri Lanka  3.898               1.361           1.179
# 4   Bangladesh  3.886               1.122           0.249
# 5  Afghanistan  1.721               0.628           0.000
#
#    Healthy life expectancy  Freedom to make life choices  Generosity  \
# 0                    0.443                         0.653       0.209
# 1                    0.321                         0.542       0.144
# 2                    0.417                         0.767       0.174
# 3                    0.586                         0.583       0.144
# 4                    0.513                         0.775       0.140
# 5                    0.242                         0.000       0.091
#
#    Perceptions of corruption  Dystopia + residual  GDP-Score Gap
# ...

# %%
#ranking south asian countries in both ascending and desending order
# ascending order
south_asian_data.sort_values(by='GDP-Score Gap', ascending=True)
# Out:
#   Country name  score  Log GDP per capita  Social support  \
# 5  Afghanistan  1.721               0.628           0.000
# 3    Sri Lanka  3.898               1.361           1.179
# 4   Bangladesh  3.886               1.122           0.249
# 2        India  4.054               1.166           0.653
# 1     Pakistan  4.657               1.069           0.600
# 0        Nepal  5.158               0.965           0.990
#
#    Healthy life expectancy  Freedom to make life choices  Generosity  \
# 5                    0.242                         0.000       0.091
# 3                    0.586                         0.583       0.144
# 4                    0.513                         0.775       0.140
# 2                    0.417                         0.767       0.174
# 1                    0.321                         0.542       0.144
# 0                    0.443                         0.653       0.209
#
#    Perceptions of corruption  Dystopia + residual  GDP-Score Gap
# ...

# %%
# descending order
south_asian_data.sort_values(by='GDP-Score Gap', ascending=False)
# Out:
#   Country name  score  Log GDP per capita  Social support  \
# 0        Nepal  5.158               0.965           0.990
# 1     Pakistan  4.657               1.069           0.600
# 2        India  4.054               1.166           0.653
# 4   Bangladesh  3.886               1.122           0.249
# 3    Sri Lanka  3.898               1.361           1.179
# 5  Afghanistan  1.721               0.628           0.000
#
#    Healthy life expectancy  Freedom to make life choices  Generosity  \
# 0                    0.443                         0.653       0.209
# 1                    0.321                         0.542       0.144
# 2                    0.417                         0.767       0.174
# 4                    0.513                         0.775       0.140
# 3                    0.586                         0.583       0.144
# 5                    0.242                         0.000       0.091
#
#    Perceptions of corruption  Dystopia + residual  GDP-Score Gap
# ...

# %%
# Sort data for the largest and smallest positive gaps
largest_positive_gap_countries = south_asian_data.sort_values(by='GDP-Score Gap', ascending=False).head(3)['Country name']
largest_positive_gap_gdp = south_asian_data.sort_values(by='GDP-Score Gap', ascending=False).head(3)['GDP-Score Gap']

least_positive_gap_countries = south_asian_data.sort_values(by='GDP-Score Gap', ascending=True).head(3)['Country name']
least_positive_gap_gdp = south_asian_data.sort_values(by='GDP-Score Gap', ascending=True).head(3)['GDP-Score Gap']

# Plotting the bars
plt.figure(figsize=(10, 6))

# Plot least positive gaps
plt.bar(least_positive_gap_countries, least_positive_gap_gdp, color='#1F77B4', label='Least Positive Gaps')

# Plot largest positive gaps
plt.bar(largest_positive_gap_countries, largest_positive_gap_gdp, color='#FFA07A', label='Top Positive Gaps')

# Labels and title
plt.xlabel('Countries')
plt.ylabel('GDP-Score Gap')
plt.title('Countries with Top and Least Positive GDP-Score Gaps')

plt.xticks(rotation=45)
plt.legend()
plt.tight_layout()

plt.show()

# %% [markdown]
# 3.3 Problem-3
# 1 - Setup Task - Preparing the Middle Eastern Dataset

# %%
middle_east_countries = [ 
    "Bahrain", "Iran", "Iraq", "Israel", "Jordan",
    "Kuwait", "Lebanon", "Oman", "Palestine", "Qatar", 
    "Saudi Arabia", "Syria", "United Arab Emirates", "Yemen"
]

middle_east_data = data_set[data_set['Country name'].isin(middle_east_countries)]

middle_east_data.to_csv('middle_east_countries_filtered.csv', index=False)

middle_east_data
# Out:
#              Country name  score  Log GDP per capita  Social support  \
# 4                  Israel  7.341               1.803           1.513
# 12                 Kuwait  6.951               1.845           1.364
# 21   United Arab Emirates  6.733               1.983           1.164
# 27           Saudi Arabia  6.594               1.842           1.361
# 89                   Iraq  5.166               1.249           0.996
# 97                   Iran  4.923               1.435           1.136
# 121                Jordan  4.186               1.262           0.983
# 129                 Yemen  3.561               0.671           1.281
# 138               Lebanon  2.707               1.377           0.577
#
#      Healthy life expectancy  Freedom to make life choices  Generosity  \
# 4                      0.740                         0.641       0.153
# 12                     0.661                         0.827       0.200
# ...

# %% [markdown]
# 1. Descriptive Statistics

# %%
#Descriptive Statistics(mean, standard deviation)
mean_middle_east = middle_east_data['score'].mean()
std_south_asia = south_asian_data['score'].std()
mean_south_asia = south_asian_data['score'].mean()
std_middle_east = middle_east_data['score'].std()

print("Mean of 'score' in Middle East countries:", mean_middle_east)
print()
print("Standard deviation of 'score' in South Asian countries:", std_south_asia)
print()
print("Mean of 'score' in South Asian countries:", mean_south_asia)
print()
print("Standard deviation of 'score' in Middle East countries:", std_middle_east)
print()
print("CONCLUSION: 5.41 is higher than 3.90, the Middle East region has a higher average happiness score.")
# Out:
# Mean of 'score' in Middle East countries: 5.351333333333333
#
# Standard deviation of 'score' in South Asian countries: 1.1770690152521504
#
# Mean of 'score' in South Asian countries: 3.895666666666667
#
# Standard deviation of 'score' in Middle East countries: 1.648656346847335
#
# CONCLUSION: 5.41 is higher than 3.90, the Middle East region has a higher average happiness score.

# %% [markdown]
#  2. Top and Bottom Performers:

# %%
#top 3 from south asia
south_asian_data.sort_values(by = 'score',ascending = False).head(3)
# Out:
#   Country name  score  Log GDP per capita  Social support  \
# 0        Nepal  5.158               0.965           0.990
# 1     Pakistan  4.657               1.069           0.600
# 2        India  4.054               1.166           0.653
#
#    Healthy life expectancy  Freedom to make life choices  Generosity  \
# 0                    0.443                         0.653       0.209
# 1                    0.321                         0.542       0.144
# 2                    0.417                         0.767       0.174
#
#    Perceptions of corruption  Dystopia + residual  GDP-Score Gap
# 0                      0.115                1.783          4.193
# 1                      0.074                1.907          3.588
# 2                      0.122                0.756          2.888

# %%
#top 3 from middle east
middle_east_data.sort_values(by = 'score',ascending = False).head(3)
# Out:
#             Country name  score  Log GDP per capita  Social support  \
# 4                 Israel  7.341               1.803           1.513
# 12                Kuwait  6.951               1.845           1.364
# 21  United Arab Emirates  6.733               1.983           1.164
#
#     Healthy life expectancy  Freedom to make life choices  Generosity  \
# 4                     0.740                         0.641       0.153
# 12                    0.661                         0.827       0.200
# 21                    0.563                         0.815       0.209
#
#     Perceptions of corruption  Dystopia + residual
# 4                       0.193                2.298
# 12                      0.172                1.884
# 21                      0.258                1.741

# %%
#last 3 from south asia
south_asian_data.sort_values(by = 'score',ascending = False).tail(3)
# Out:
#   Country name  score  Log GDP per capita  Social support  \
# 3    Sri Lanka  3.898               1.361           1.179
# 4   Bangladesh  3.886               1.122           0.249
# 5  Afghanistan  1.721               0.628           0.000
#
#    Healthy life expectancy  Freedom to make life choices  Generosity  \
# 3                    0.586                         0.583       0.144
# 4                    0.513                         0.775       0.140
# 5                    0.242                         0.000       0.091
#
#    Perceptions of corruption  Dystopia + residual  GDP-Score Gap
# 3                      0.031                0.014          2.537
# 4                      0.167                0.919          2.764
# 5                      0.088                0.672          1.093

# %%
#last3 from middle east
middle_east_data.sort_values(by = 'score',ascending = False).tail(3)
# Out:
#     Country name  score  Log GDP per capita  Social support  \
# 121       Jordan  4.186               1.262           0.983
# 129        Yemen  3.561               0.671           1.281
# 138      Lebanon  2.707               1.377           0.577
#
#      Healthy life expectancy  Freedom to make life choices  Generosity  \
# 121                    0.594                         0.593       0.059
# 129                    0.293                         0.362       0.080
# 138                    0.556                         0.173       0.068
#
#      Perceptions of corruption  Dystopia + residual
# 121                      0.189                0.504
# 129                      0.113                0.760
# 138                      0.029               -0.073

# %%
#plot top 3 for each region
import matplotlib.pyplot as plt
best_asian_countries= south_asian_data.sort_values(by = 'score',ascending = False).head(3)['Country name']
best_middle_east_countries= middle_east_data.sort_values(by = 'score',ascending = False).head(3)['Country name']


best_asian_scores= south_asian_data.sort_values(by = 'score',ascending = False).head(3)['score']
best_middle_east_scores= middle_east_data.sort_values(by = 'score',ascending = False).head(3)['score']


plt.bar(best_asian_countries,best_asian_scores, color='skyblue', label='Top Asian')
plt.bar(best_middle_east_countries,best_middle_east_scores, color='salmon', label='Top Middle East')

plt.legend()
plt.xticks(rotation=90)

plt.xlabel('Countries')
plt.ylabel('Score')
plt.title('Top 3 countires for each region')
# Out:
# Text(0.5, 1.0, 'Top 3 countires for each region')

# %%
#plot last 3 for each region
low_asian_countries= south_asian_data.sort_values(by = 'score',ascending = True).head(3)['Country name']
low_middle_east_countries= middle_east_data.sort_values(by = 'score',ascending = True).head(3)['Country name']

low_asian_scores= south_asian_data.sort_values(by = 'score',ascending = True).head(3)['score']
low_middle_east_scores= middle_east_data.sort_values(by = 'score',ascending = True).head(3)['score']

plt.bar(low_asian_countries,low_asian_scores, color='Pink', label='Low Asian')
plt.bar(low_middle_east_countries,low_middle_east_scores, color='LightBlue', label='Low Middle East')

plt.ylim(0, 6)

plt.xticks(rotation=90)


plt.legend()
plt.xlabel('Countries')
plt.ylabel('Score')
plt.title('Last 3 countires for each region')
# Out:
# Text(0.5, 1.0, 'Last 3 countires for each region')

# %% [markdown]
# 3. Metric Comparisons

# %%
import pandas as pd
import matplotlib.pyplot as plt

south_asia_means = south_asian_data[['Log GDP per capita', 'Social support', 'Healthy life expectancy']].mean()
middle_east_means = middle_east_data[['Log GDP per capita', 'Social support', 'Healthy life expectancy']].mean()

comparison_df = pd.DataFrame({'South Asia': south_asia_means, 'Middle East': middle_east_means})

comparison_df.plot(kind='bar', figsize=(10, 6), color=['skyblue', 'salmon'])
plt.title('Comparison of Key Metrics between South Asia and Middle East')
plt.ylabel('Average Value')
plt.xlabel('Metrics')
plt.legend()

plt.tight_layout()
plt.show()

disparity = (middle_east_means - south_asia_means).abs()
print("Metric with the largest disparity:", disparity.idxmax())
# Out:
# Metric with the largest disparity: Social support

# %% [markdown]
# 4. Happiness Disparity

# %%
south_asian_data = pd.read_csv("south_asian_countries_filtered.csv")
middle_east_data = pd.read_csv("middle_east_countries_filtered.csv")

range_asian = south_asian_data['score'].max() - south_asian_data['score'].min()
range_middle = middle_east_data['score'].max() - middle_east_data['score'].min()

cv_asian = (south_asian_data['score'].std() / south_asian_data['score'].mean()) * 100
cv_middle =(middle_east_data['score'].std() / middle_east_data['score'].mean()) * 100

print(f"South Asian Region - Range: {range_asian}, CV: {cv_asian}%")
print(f"Middle East Region - Range: {range_middle}, CV: {cv_middle}%")

# Determine which region has greater variability
if cv_asian > cv_middle:
    print("South Asian region has greater variability in happiness.")
else:
    print("Middle East region has greater variability in happiness.")
# Out:
# South Asian Region - Range: 3.4370000000000003, CV: 30.21482883337427%
# Middle East Region - Range: 4.634, CV: 30.808328395054225%
# Middle East region has greater variability in happiness.

# %% [markdown]
# 5. Correlation Analysis

# %%
# Load the datasets
south_asian_data = pd.read_csv("south_asian_countries_filtered.csv")
middle_east_data = pd.read_csv("middle_east_countries_filtered.csv")

# Calculate correlations for South Asia
south_asia_corr_freedom = south_asian_data['score'].corr(south_asian_data['Freedom to make life choices'])
south_asia_corr_generosity = south_asian_data['score'].corr(south_asian_data['Generosity'])

# Calculate correlations for the Middle East
middle_east_corr_freedom = middle_east_data['score'].corr(middle_east_data['Freedom to make life choices'])
middle_east_corr_generosity = middle_east_data['score'].corr(middle_east_data['Generosity'])

# Display results
print("South Asia - Freedom:", south_asia_corr_freedom, "Generosity:", south_asia_corr_generosity)
print("Middle East - Freedom:", middle_east_corr_freedom, "Generosity:", middle_east_corr_generosity)
# Out:
# South Asia - Freedom: 0.8005185224163315 Generosity: 0.874512371253192
# Middle East - Freedom: 0.8632202433827544 Generosity: 0.6275236536964182

# %%
# Create scatter plots for South Asia
plt.figure(figsize=(10, 5))

# Score vs Freedom to make life choices
plt.subplot(1, 2, 1)
plt.scatter(south_asian_data['Freedom to make life choices'], south_asian_data['score'], color='brown')
plt.title('South Asia: Score vs Freedom')
plt.xlabel('Freedom to make life choices')
plt.ylabel('Score')

# Score vs Generosity
plt.subplot(1, 2, 2)
plt.scatter(south_asian_data['Generosity'], south_asian_data['score'], color='green')
plt.title('South Asia: Score vs Generosity')
plt.xlabel('Generosity')
plt.ylabel('Score')

plt.tight_layout()
plt.show()

# scatter plots for the Middle East
plt.figure(figsize=(10, 5))

# Score vs Freedom to make life choices
plt.subplot(1, 2, 1)
plt.scatter(middle_east_data['Freedom to make life choices'], middle_east_data['score'], color='red')
plt.title('Middle East: Score vs Freedom')
plt.xlabel('Freedom to make life choices')
plt.ylabel('Score')

# Score vs Generosity
plt.subplot(1, 2, 2)
plt.scatter(middle_east_data['Generosity'], middle_east_data['score'], color='orange')
plt.title('Middle East: Score vs Generosity')
plt.xlabel('Generosity')
plt.ylabel('Score')

plt.tight_layout()
plt.show()

# %%
#heatmap 
# Calculate correlation for South Asia
south_asian_corr = south_asian_data.select_dtypes(include=['number']).corr()

# Plot heatmap for South Asia
plt.figure(figsize=(8, 6))
sns.heatmap(south_asian_corr, annot=True, cmap='Spectral', fmt='.2f', cbar=True)
plt.title('South Asia: Correlation Heatmap')
plt.show()

# Calculate correlation for the Middle East
middle_east_corr = middle_east_data.select_dtypes(include=['number']).corr()

# Plot heatmap for the Middle East
plt.figure(figsize=(8, 6))
sns.heatmap(middle_east_corr, annot=True, cmap='PiYG', fmt='.2f', cbar=True)
plt.title('Middle East: Correlation Heatmap')
plt.show()

# %% [markdown]
# 6. Outlier Detection

# %%
# Function to identify outliers using IQR method
def identify_outliers(data, column):
    Q1 = data[column].quantile(0.25)
    Q3 = data[column].quantile(0.75)
    IQR = Q3 - Q1
    lower_bound = Q1 - 1.5 * IQR
    upper_bound = Q3 + 1.5 * IQR
    return data[(data[column] < lower_bound) | (data[column] > upper_bound)]

# Identify outliers for South Asia
south_asia_score_outliers = identify_outliers(south_asian_data, 'score')
south_asia_gdp_outliers = identify_outliers(south_asian_data, 'Log GDP per capita')

# Identify outliers for the Middle East
middle_east_score_outliers = identify_outliers(middle_east_data, 'score')
middle_east_gdp_outliers = identify_outliers(middle_east_data, 'Log GDP per capita')

# Print outliers for South Asia
print("South Asia - Score Outliers:")
print(south_asia_score_outliers[['Country name', 'score']])

print("\nSouth Asia - GDP per Capita Outliers:")
print(south_asia_gdp_outliers[['Country name', 'Log GDP per capita']])

# Print outliers for the Middle East
print("\nMiddle East - Score Outliers:")
print(middle_east_score_outliers[['Country name', 'score']])

print("\nMiddle East - GDP per Capita Outliers:")
print(middle_east_gdp_outliers[['Country name', 'Log GDP per capita']])
# Out:
# South Asia - Score Outliers:
#   Country name  score
# 5  Afghanistan  1.721
#
# South Asia - GDP per Capita Outliers:
#   Country name  Log GDP per capita
# 5  Afghanistan               0.628
#
# Middle East - Score Outliers:
# Empty DataFrame
# Columns: [Country name, score]
# Index: []
#
# Middle East - GDP per Capita Outliers:
# Empty DataFrame
# Columns: [Country name, Log GDP per capita]
# Index: []

# %%
# Function to plot data and highlight outliers
def visualize_data_with_outliers(data, outliers, x, y, title, x_label, y_label):
    plt.figure(figsize=(16, 8))
    
    # Plot regular data
    plt.scatter(data[x], data[y], label='Normal', color='purple')
    
    # Highlight outliers
    plt.scatter(outliers[x], outliers[y], color='red', label='Outliers')
    
    # Add labels and title
    plt.title(title)
    plt.xlabel(x_label)
    plt.ylabel(y_label)
    plt.legend()
    plt.grid()
    plt.show()

# Plot South Asia - Score Outliers
visualize_data_with_outliers(
    south_asian_data,
    south_asia_score_outliers,
    x='Country name',
    y='score',
    title='South Asia - Score Outliers',
    x_label='Country',
    y_label='Score'
)

# Plot South Asia - GDP Outliers
visualize_data_with_outliers(
    south_asian_data,
    south_asia_gdp_outliers,
    x='Country name',
    y='Log GDP per capita',
    title='South Asia - GDP Outliers',
    x_label='Country',
    y_label='Log GDP'
)

# Plot Middle East - Score Outliers
visualize_data_with_outliers(
    middle_east_data,
    middle_east_score_outliers,
    x='Country name',
    y='score',
    title='Middle East - Score Outliers',
    x_label='Country',
    y_label='Score'
)

# Plot Middle East - GDP Outliers
visualize_data_with_outliers(
    middle_east_data,
    middle_east_gdp_outliers,
    x='Country name',
    y='Log GDP per capita',
    title='Middle East - GDP Outliers',
    x_label='Country',
    y_label='Log GDP'
)

# %% [markdown]
# 7.Visualization

# %%
#boxplot
south_asian_data['Region'] = 'South Asia'
middle_east_data['Region'] = 'Middle East'

combined_data = pd.concat([south_asian_data, middle_east_data], ignore_index=True)

plt.figure(figsize=(10, 6))
sns.boxplot(data=combined_data, x='Region', y='score', palette=['salmon', 'skyblue'])

plt.title('South Asia vs Middle East (Score Distribution)', fontsize=14)
plt.xlabel('Region', fontsize=12)
plt.ylabel('Score', fontsize=12)
plt.tight_layout()
plt.show()

# %%
#heatmap for whole data
import matplotlib.pyplot as plt
import seaborn as sns

# Calculate correlation for the dataset
data_corr = data_set.select_dtypes(include=['number']).corr()


plt.figure(figsize=(12, 10))  
sns.heatmap(data_corr, annot=True, cmap='coolwarm', fmt='.2f', cbar=True)
plt.title('Dataset: Correlation Heatmap')
plt.show()

# %%
data_set.describe() #statistical information of whole data
# Out:
#             score  Log GDP per capita  Social support  \
# count  140.000000          140.000000      140.000000
# mean     5.530893            1.378807        1.134329
# std      1.181247            0.425098        0.333317
# min      1.721000            0.000000        0.000000
# 25%      4.631750            1.077750        0.921750
# 50%      5.800500            1.431500        1.237500
# 75%      6.426250            1.741500        1.383250
# max      7.741000            2.141000        1.617000
#
#        Healthy life expectancy  Freedom to make life choices  Generosity  \
# count               140.000000                    140.000000  140.000000
# mean                  0.520886                      0.620621    0.146271
# std                   0.164923                      0.162492    0.073441
# min                   0.000000                      0.000000    0.000000
# 25%                   0.398000                      0.527500    0.091000
# ...

# %%
south_asian_data.describe() #statistical information of south asian data
# Out:
#           score  Log GDP per capita  Social support  Healthy life expectancy  \
# count  6.000000            6.000000        6.000000                 6.000000
# mean   3.895667            1.051833        0.611833                 0.420333
# std    1.177069            0.245361        0.441024                 0.125082
# min    1.721000            0.628000        0.000000                 0.242000
# 25%    3.889000            0.991000        0.336750                 0.345000
# 50%    3.976000            1.095500        0.626500                 0.430000
# 75%    4.506250            1.155000        0.905750                 0.495500
# max    5.158000            1.361000        1.179000                 0.586000
#
#        Freedom to make life choices  Generosity  Perceptions of corruption  \
# count                      6.000000    6.000000                   6.000000
# mean                       0.553333    0.150333                   0.099500
# ...

# %%
middle_east_data.describe() #statistical information of middle east data
# Out:
#           score  Log GDP per capita  Social support  Healthy life expectancy  \
# count  9.000000            9.000000        9.000000                 9.000000
# mean   5.351333            1.496333        1.152778                 0.554111
# std    1.648656            0.416414        0.278277                 0.123047
# min    2.707000            0.671000        0.577000                 0.293000
# 25%    4.186000            1.262000        0.996000                 0.511000
# 50%    5.166000            1.435000        1.164000                 0.563000
# 75%    6.733000            1.842000        1.361000                 0.594000
# max    7.341000            1.983000        1.513000                 0.740000
#
#        Freedom to make life choices  Generosity  Perceptions of corruption  \
# count                      9.000000    9.000000                   9.000000
# mean                       0.554333    0.139889                   0.145889
# ...
